# %% [markdown]
# <a href="https://colab.research.google.com/github/zeguii/POO-IFCE/blob/main/POO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Funcionario:
  def __init__(self,cargo,nome,salario):
    self._cargo = cargo
    self._nome = nome
    self._salario = salario

class Analista(Funcionario):
  def __init__(self,nome,salario):
    super().__init__("Analista",nome,salario)
    self.certificacoes = []
    self._chamados = []

class Caixa(Funcionario):
  def __init__(self,nome,salario):
    super().__init__("Caixa",nome,salario)
    self.guiche = None
    self._turno_atendimento = None
    self._limite_operacao = None
    self.__meta_anual = None

class Gerente(Funcionario):
  def __init__(self,nome,salario):
    super().__init__("Gerente",nome,salario)
    self._equipe = []
    self._meta_anual = None
    self.__clientes_vip = []
    self.__bonus = None

# %%
class Usuario:
  def __init__(self,nome,email):
    self._nome = nome
    self.email = email
  @property
  def nome(self):
    return self._nome

class Aluno(Usuario):
  def __init__(self,nome,email,matricula,disciplinas):
    super().__init__(nome,email)
    self.matricula = matricula
    self._disciplinas = []

class Professor(Usuario):
  def __init__(self,nome,email,disciplinas_ministradas,carga_horaria,salario):
    super().__init__(nome,email)
    self._disciplinas_ministradas = []
    self._carga_horaria = None
    self.__salario = None

class Coordenador(Usuario):
   def __init__(self,nome,email,curso,professores,bonus):
    super().__init__(nome, email)
    self._curso = None
    self._professores = []
    self.__bonus = None

A1 = Aluno("Gui","gui@ao.com",123,"matematica")

# %%
class Funcionario:
  def __init__(self,cargo,nome,salario):
    self._cargo = cargo
    self._nome = nome
    self._salario = salario
  def contra_cheque(self):
    print(self._salario)

class Analista(Funcionario):
  def __init__(self,nome,salario):
    super().__init__("Analista",nome,salario)
    self.certificacoes = []
    self._chamados = []
  def contra_cheque(self):
    super().contra_cheque()

class Caixa(Funcionario):
  def __init__(self,nome,salario):
    super().__init__("Caixa",nome,salario)
    self.guiche = None
    self._turno_atendimento = None
    self._limite_operacao = None
    self.__meta_anual = None

# %%
class Pedido:
  def __init__(self,cliente,valor_base):
    self._cliente = cliente
    self._valor_base = valor_base
  def total(self):
    return self._valor_base

class Pedido_Normal(Pedido):
  pass

class Pedido_com_desconto(Pedido):
  def __init__(self,cliente,valor_base,desconto):
    super().__init__(cliente,valor_base)
    self._desconto = 20
  def total(self):
    return self._valor_base *(1 - self._desconto/100)

class Pedido_Expresso(Pedido):
  def __init__(self,cliente,valor_base,taxa_entrega):
    super().__init__(cliente,valor_base)
    self._taxa_entrega = 3
    total

# %%
from abc import ABC, abstractmethod

class Pagamento(ABC):
  @abstractmethod
  def validar(self):
    pass

  @abstractmethod
  def processar(self):
    pass

  def registrar(self):
    print("ENTREGAR")

  def executar(self):
    self.validar()
    self.processar()
    self.registrar()

class PagamentoPix(Pagamento):
  def validar(self):
    print("validando chave Pix")

  def processar(self):
    print("Transferindo")

# %%
class Calculadora:
  log_operacao = []

  @classmethod
  def divisao(cls,a,b):
    try:
      operacao = f"{a}/{b} = {a/b:.2f}"
    except ZeroDivisionError:
      operacao = f"{a}/{b}: divisão por zero"
    except TypeError:
      operacao = f"{a}/{b}: tipo inválido"

  cls.log_operacao.append(operacao)
  return operacao

# %%
class Calculadora:
  log_operacao = []

  @classmethod
  def divisao(cls,a,b):
    try:
      operacao = f"{a}/{b} = {a/b}"
    except ZeroDivisionError:
      operacao = f"{a}/{b}: divisao por zero"
      return None
    except TypeError:
      operacao = f"{a}/{b}: tipo inválido"
      return None
    except:
      pass
    else:
      operacao = f"{operacao} = {resultado:.2}"
    finally:
      cls.log_operacao.append(operacao)

# %%
while True:
  try:
    variavel = float(input())
  except TypeError:
    print("Não aceito letra")
  else:
    break

# %%
def calcular():
  while True:
    try:
      a = float(input())
      b = float(input())
      resultado = a/b
    except ZeroDivisionError:
      print("Divisao por zero")

    return resultado

print(calcular())
# Out:
# 1
# 0
# Divisao por zero
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_9323/3404733150.py in <cell line: 0>()
#      10     return resultado
#      11
# ---> 12 print(calcular())
#
# /tmp/ipykernel_9323/3404733150.py in calcular()
#       8       print("Divisao por zero")
#       9
# ---> 10     return resultado
#      11
#      12 print(calcular())
#
# UnboundLocalError: cannot access local variable 'resultado' where it is not associated with a value

# %%
def calcular():
  a = float(input())
  b = float(input())
  try:
    resultado = a/b
  except:
    print("ERRO DIVISAO")
  else:
    print("go")

# %%
def encontrar(lista,indice):
  try:
    valor = lista[indice]
    return valor
  except IndexError:
    print("Indice nao existente")
    return Valor
lista = [1,2]
print(encontrar(lista,5))
# Out:
# Indice nao existente
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_9323/3612895877.py in encontrar(lista, indice)
#       2   try:
# ----> 3     valor = lista[indice]
#       4     return valor
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9323/3612895877.py in <cell line: 0>()
#       7     return Valor
#       8 lista = [1,2]
# ----> 9 print(encontrar(lista,5))
#
# /tmp/ipykernel_9323/3612895877.py in encontrar(lista, indice)
#       5   except IndexError:
#       6     print("Indice nao existente")
# ----> 7     return Valor
#       8 lista = [1,2]
#       9 print(encontrar(lista,5))
#
# NameError: name 'Valor' is not defined

# %%
def teste():
  try:
    a = 1
    b = float(input())
    dividir = a/b
  except ValueError and TypeError:
    print("Erro")
  finally:
    return dividir
print(teste())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9323/2949271722.py in teste()
#       3     a = 1
# ----> 4     b = float(input())
#       5     dividir = a/b
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#
# KeyboardInterrupt: Interrupted by user
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import math

def calcular(num):
  if num < 0:
    raise ValueError("Número menor que zero")
  return math.sqrt(num)

  try:
    a = int(input())
    return calcular(a)
  except ValueError as e:
      print("Numero errado")

# %%
dic = [1,2]

def dic(dic,num):
  try:
    valor = dic[num]
  except KeyError:
    print("Sem dicionario")

# %%
try:
  print(1+1)
finally:
  print("Oi")
# Out:
#   File "/tmp/ipykernel_9323/1144459854.py", line 3
#     return f"pedra"
#     ^
# SyntaxError: 'return' outside function

# %%
import abc from ABC, abstractmethod

class Armazenamento(ABC):
  @abstractmethod
  def conectar(self):
    pass
  @abstractmethod
  def salvar(self):
    pass

  def executar(self,arquivo):
    status_conexao = self.conetar
    print(f"Conexâo: {status_conexao}")
    if status_conexao == 'SUCESS':
      self.salvar(arquivo)

import random
class Disco(Armazenamento):
  def __init__(self,caminho):
    self._caminho = caminho
  def conectar(self):
    print(f"Conectando ao {self._caminho}")
    return random.choice(['SUCESS','FAIL'])

class Nuvem:
  def __init__(self,token):
    self._token = token

# %%
class Usuario:
  def __init__(self,nome):
    self._nome = nome

class Aluno(Usuario):
  def __init__(self,nome)
  super().__init__(nome)
  self._matricula = None
  self._disciplina = []

# %%
class Funcionario:
  def __init__(self,nome,contra_cheque):
    self._nome = nome
    self._email = email
    self._contra_cheque

class Analista(Funcionario):
  def __init__(self,nome,contra_cheque,beneficio):
    super().__init__(nome,contra_cheque)
    self._beneficio = beneficio

  def beneficio(self):
    dinheiro = self._beneficio
    return dinheiro*10

# %%
class Whatsapp:
  def __init__(self,numero):
    def.numero = numero

  def enviar(self,mensagem):
    print(f"Enviando mensagem para: {self.numero} : {mensagem}")

def DispararMensagem(comunicador,texto):
  comunicador.enviar(texto)

num = Whatsapp(88)
mensagem = DispararMensagem(num,"OI")

# %%
import abc from ABC, abstractmethod

class Pagamento(ABC):
  @abstractmethod
  def validar(pass):
    pass
  @abstractmethod
  def processar(pass):
    pass

class PagamentoPix(Pagamento):
  def __init__(self,valor):
    self.valor = valor

  def processar(self):
    print("Processando...")
